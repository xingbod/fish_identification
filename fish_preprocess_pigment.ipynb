# %%
import matplotlib.pyplot as plt
from utils import *
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img,save_img
import glob
import os
 
orig_path ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1'
SAVE_PATH ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION_PIGMENT'
alllist = getfilelist(orig_path)
num_imgs=len(alllist);
print('total number of images:',num_imgs)

# %% [markdown]
# ## SESSION1 The save path can not be define here, need modify the utils.py and restart kernal

# %%
import threading
import time
import matplotlib.pyplot as plt
from utils import *
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img,save_img
import glob
import os
import concurrent.futures

import logging
import numpy as np
from matplotlib import pyplot as plt
import cv2
from pigementUtil import * 

orig_path ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_ST'
SAVE_PATH ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION_PIGMENT'

mypigementUtil = pigementUtil(SAVE_PATH)

# 创建Process Pool，默认为电脑的每个CPU创建一个
with concurrent.futures.ProcessPoolExecutor() as executor:
    # 获取需要处理的文件列表
    image_files = getfilelist(orig_path)
    # 处理文件列表，但通过Process Pool划分工作，使用全部CPU！
    for img in zip(image_files, executor.map(mypigementUtil.transform2pigment, image_files)):
        print('processed')

# %% [markdown]
# ## SESSION 2

# %%
import threading
import time
import matplotlib.pyplot as plt
from utils import *
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img,save_img
import glob
import os
import concurrent.futures


import logging
import numpy as np
from matplotlib import pyplot as plt
import cv2
from pigementUtil import * 
orig_path ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2'
SAVE_PATH ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2_PIGMENT'
mypigementUtil = pigementUtil(SAVE_PATH)

# 创建Process Pool，默认为电脑的每个CPU创建一个
with concurrent.futures.ProcessPoolExecutor() as executor:
    # 获取需要处理的文件列表
    image_files = getfilelist(orig_path)

    # 处理文件列表，但通过Process Pool划分工作，使用全部CPU！
    for img in zip(image_files, executor.map(mypigementUtil.process2pigment, image_files)):
        print('processed')
# Out:
# stop at: 40
# stop at: 55
# stop at: 45
# stop at: 45
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2/54B9F0/fish_2_54B9F0__07.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2_PIGMENT/54B9F0
# stop at: 55
# stop at: 55
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2/54B9F0/fish_2_54B9F0__09.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2_PIGMENT/54B9F0
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2/FCFE4F/fish_2_FCFE4F__09.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2_PIGMENT/FCFE4F
# processed
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2/54B9F0/fish_2_54B9F0__01.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION2_PIGMENT/54B9F0
# ...

# %% [markdown]
# ## SESSION3

# %%
import threading
import time
import matplotlib.pyplot as plt
from utils import *
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img,save_img
import glob
import os
import concurrent.futures


import logging
import numpy as np
from matplotlib import pyplot as plt
import cv2
from pigementUtil import * 
orig_path ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3'
SAVE_PATH ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3_PIGMENT'
mypigementUtil = pigementUtil(SAVE_PATH)

# 创建Process Pool，默认为电脑的每个CPU创建一个
with concurrent.futures.ProcessPoolExecutor() as executor:
    # 获取需要处理的文件列表
    image_files = getfilelist(orig_path)

    # 处理文件列表，但通过Process Pool划分工作，使用全部CPU！
    for img in zip(image_files, executor.map(mypigementUtil.process2pigment, image_files)):
        print('processed')
# Out:
# stop at: 45
# stop at: 60
# stop at: 45
# stop at: 60
# stop at: 50
# stop at: 55
# stop at: 45
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3/54B9F0/fish_2_54B9F0_03.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3_PIGMENT/54B9F0
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3/54B9F0/fish_2_54B9F0_09.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3_PIGMENT/54B9F0
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3/FCFE4F/fish_2_FCFE4F_07.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3_PIGMENT/FCFE4F
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3/54B9F0/fish_2_54B9F0_04.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION3_PIGMENT/54B9F0
# ...

# %%
import threading
import time
import matplotlib.pyplot as plt
from utils import *
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array,load_img,save_img
import glob
import os
import concurrent.futures


import logging
import numpy as np
from matplotlib import pyplot as plt
import cv2
from pigementUtil import * 
orig_path ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_LT'
SAVE_PATH ='/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_PIGMENT_LT'
mypigementUtil = pigementUtil(SAVE_PATH)

# 创建Process Pool，默认为电脑的每个CPU创建一个
with concurrent.futures.ProcessPoolExecutor() as executor:
    # 获取需要处理的文件列表
    image_files = getfilelist(orig_path)

    # 处理文件列表，但通过Process Pool划分工作，使用全部CPU！
    for img in zip(image_files, executor.map(mypigementUtil.process2pigment, image_files)):
        print('processed')
# Out:
# stop at: 45
# stop at: 55
# stop at: 55
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_LT/FCFE4F/fish_2_FCFE4F__5.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_PIGMENT_LT/FCFE4F
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_LT/54B9F0/fish_2_54B9F0__3.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_PIGMENT_LT/54B9F0
# stop at: 50
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_LT/FCFE4F/fish_2_FCFE4F__4.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_PIGMENT_LT/FCFE4F
# stop at: 50
# processing:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_LT/54B9F0/fish_2_54B9F0__1.png
# saving:/media/xingbo/Storage/fish_identification/data/SESSION_AQUARIUM/SESSION1_PIGMENT_LT/54B9F0
# ...
